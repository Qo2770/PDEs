# %%
from Poisson2d import *

# %%
L = 1
N = 32

h = L/N
x = np.arange(N)*h
y = np.arange(N)*h
xx, yy = np.meshgrid(x, y)

# %%
f = construct_f(xx, yy, N=N, L=L)
u = poisson_2d(f, N=N, L=1)

# %%
plot_surf(f, xx, yy)

# %%
plot_surf(u, xx, yy)
